# %% [markdown]
# # Assignment #1
# Daniel Scanks
# V00788200

# %% [markdown]
# # Q1: Simulate aliasing of sinusoidal signals
# For this problem you will simulate the phenomena of aliasing. This will give you pracitice in making synthetic time series, subsetting data, and plotting your results.
# 1) To start, make a time vector that goes from 0 to 120 s, with 10000 entries in it. Then make a synthetic time series that has two close in frequency sine waves:
# x=A1cos(ωt)+A2cos((ω1+δω)t)
# where ω is the "carrier" frequency, and δω<<ω is the difference in frequencies between the two waves. For simplicty, you could make A1=A2=1.[V]. Feel free to choose an interesting ω.
#
#
# 2) Now plot the two component waves and the full value of x as a time series. Preferably on the same axis. Make sure to label your axes and include a legend
#
# 3) Try a few different values of δω, and compare

# %%
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
                                #1)
t= np.linspace(0.,120.,10000) #time vector
x= np.cos(np.pi/20 * t) + np.cos((np.pi/20 + np.pi/180)*t) #time series ( supersposition of both waves )
c1 = np.cos(np.pi/20 * t) #first wave component
c2 = np.cos((np.pi/20 + np.pi/180)*t) #second wave component

                                #2)

fig = plt.figure(figsize = (8,6))
fig.suptitle('Original', fontsize=14, fontweight='bold')
ax= fig.add_subplot(111)
ax.plot(t,x, 'g^', label='full value of x') 
ax.plot(t,c1, 'bs', label='comp 1 of x')
ax.plot(t,c2, 'rs', label='comp 2 of x')  
ax.set_xlabel('Time t (s)')
ax.set_ylabel('Position x')
ax.legend(loc=0)

                                #3)
#δ=pi/100
t= np.linspace(0.,120.,10000) #time vector
x= np.cos(np.pi/20 * t) + np.cos((np.pi/20 + np.pi/100)*t) #time series ( supersposition of both waves )
c1 = np.cos(np.pi/20 * t) #first wave component
c2 = np.cos((np.pi/20 + np.pi/100)*t) #second wave component


fig = plt.figure(figsize = (8,6))
fig.suptitle('pi/100 phase', fontsize=14, fontweight='bold') #changed phase difference 
ax= fig.add_subplot(111)
ax.plot(t,x, 'gs', label='full value of x') 
ax.plot(t,c1, 'bs', label='comp 1 of x')
ax.plot(t,c2, 'rs', label='comp 2 of x')  
ax.set_xlabel('Time t (s)')
ax.set_ylabel('Position x')
ax.legend(loc=0)

#δ=pi/50
t= np.linspace(0.,120.,10000) #time vector
x= np.cos(np.pi/20 * t) + np.cos((np.pi/20 + np.pi/50)*t) #time series ( supersposition of both waves )
c1 = np.cos(np.pi/20 * t) #first wave component
c2 = np.cos((np.pi/20 + np.pi/50)*t) #second wave component


fig = plt.figure(figsize = (8,6))
fig.suptitle('pi/50 phase', fontsize=14, fontweight='bold') #changed phase difference 
ax= fig.add_subplot(111)
ax.plot(t,x, 'gs', label='full value of x') 
ax.plot(t,c1, 'bs', label='comp 1 of x')
ax.plot(t,c2, 'rs', label='comp 2 of x')  
ax.set_xlabel('Time t (s)')
ax.set_ylabel('Position x')
ax.legend(loc=0)

#δ=0
t= np.linspace(0.,120.,10000) #time vector
x= np.cos(np.pi/20 * t) + np.cos((np.pi/20)*t) #time series ( supersposition of both waves )
c1 = np.cos(np.pi/20 * t) #first wave component
c2 = np.cos((np.pi/20)*t) #second wave component

fig = plt.figure(figsize = (8,6))
fig.suptitle('0 phase', fontsize=14, fontweight='bold') #changed phase difference 
ax= fig.add_subplot(111)
ax.plot(t,x, 'gs', label='full value of x') 
ax.plot(t,c1, 'bs', label='comp 1 of x')
ax.plot(t,c2, 'rs', label='comp 2 of x')  
ax.set_xlabel('Time t (s)')
ax.set_ylabel('Position x')
ax.legend(loc=0)

# %% [markdown]
# 3) Ans: When altering the phase difference and observing the changes in the graph, I found that a small phase change slowly differentiates the components of the total wave and therfore reduces and then increases the amplitude of the total time series over a long period. Overall, larger phase differences in the component waves cause faster-occuring variance in the combined wave and the opposite is true for small phase differences. No phase differences means the components are equal and the total wave will be a 100% constructive superposition of the two component waves.
#
#
# 4) Now, just so this works, let me specify some numbers for you. Make ω=2π/3, and δω=ω/10.. Plot the original time series, and a subsampled time series that just consists of every 200th point. In a "Markdown" box below the code (or as a comment) describe the difference in these two signals as quantifiably as you can.

# %%
                                #4)
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
                                
t= np.linspace(0.,120.,10000) #time vector
x= np.cos(np.pi*2/3 * t) + np.cos((np.pi*2/3 + np.pi/15)*t) # original time series ( supersposition of both waves )

#plotting with original time vector
fig = plt.figure(figsize = (8,6))
fig.suptitle('Original with given values', fontsize=14, fontweight='bold')
ax= fig.add_subplot(111)
ax.plot(t,x, 'g^', label='full value of x')   
ax.set_xlabel('Time t (s)')
ax.set_ylabel('Position x')
ax.legend(loc=0)


m= np.linspace(0.,120.,50) #time vector with 1/200 the points of t
v= np.cos(np.pi*2/3 * m) + np.cos((np.pi*2/3 + np.pi/15)*m) # original time series ( supersposition of both waves )

#plotting the subset of time data
fig = plt.figure(figsize = (8,6))
fig.suptitle('Subset with given values', fontsize=14, fontweight='bold')
ax= fig.add_subplot(111)
ax.plot(m,v, 'b--', label='full value of x')   
ax.set_xlabel('Time t (s)')
ax.set_ylabel('Position x')
ax.legend(loc=0)

# %% [markdown]
# The subset has too little points to see the wave-packet-like pattern the original time series portrays. Both graphs show a symmetry of some kind about the vertical line t=60s. The signals are the same, but the subset represents a lack of data leading to an incomplete visualization of the time series.

# %% [markdown]
# Q2: Demonstrate the central limit theorem for a very unfair coin flip.
# Consider a coin that is twice as likely to come up heads as tails. To put a number on it, call tails x=−1/2 and heads x=+1/2.
# 1) What are the mean, μx, and variance σ2x of this process?

# %%
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

#probability that x=1/2 (heads) is 2/3
#probability that x=-1/2 (tails) is 1/3
meanx = ((2./3.)*(1./2.))+((1./3.)*(-1./2.))
print(meanx) #mean value of process = (1/6)
variancex = ((((-1./2.)-(1./6.))**2.)*(1./3.))+((2./3.)*(((1./2.)-(1./6.))**2.)) #variance calculation = (2/9)
print(variancex)
# Out:
# 0.166666666667
# 0.222222222222

# %% [markdown]
# 2) Plot or represent the probability distribution (or cumulative distrubution) of this process.

# %% [markdown]
# 2)ans:
#
# P(x)= 1/3, if x=-1/2
#       2/3, if x=1/2
#       0, if anything else(not possible)
#
# 3) Write a function using the np.random.rand function to simulate the coin flip. It should return +1/2+ twice as often as −1/2. Demonstrate that your function works.

# %%
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

 
a= 0
for a in range(0,5):  #H stands for heads (2/3 probability) and tails is T (1/3 probability) for loop repeats coin flip 5 times  
    a= a+1               #can change the amount of flips by increasing range of for loop
    x = np.random.rand()
    if x<0.6667:
        print "H"
    else:
        print "T"
# Out:
# T
# H
# T
# H
# H

# %% [markdown]
# 4) Perform Nflip and take the sample mean x¯¯¯ of the values. Do this 2000 times, and show that as Nflip→∞ the distribution of x¯¯¯ approaches a Normal distribution by plotting the histograms of the means for each. For Nflip choose 2, 16, 64, 256.
# Comment on how the convergence of x¯¯¯ for the unfair coin compares to the convergence of the sample mean of the dice roll from the notes.

# %%
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

def cointoss(tosses):
    x = np.random.rand(tosses) #
    for b in range(0, tosses):
        if x[b]<.67777:
            x[b]=0.5
        else: x[b]=-0.5
    return np.mean(x)

print cointoss(2000)

def coinhist(tosses):
    x2000 = np.zeros(2000)
    for i in range(0,2000,1):
        x2000[i] = cointoss(tosses)
    fig=plt.figure()
    fig = plt.hist(x2000,50)
    plt.title(str(tosses) + ' tosses')
    plt.xlabel('mean values')
    plt.ylabel('frequency of occurance')

coinhist(2)
coinhist(16)
coinhist(64)
coinhist(256)
 
#4) the convergence of the biased coin flip and the dice roll both show a gaussian-like distribution when the average mean is graphed
# as a histogram. Where the sample mean values converge around the calculated mean.
# Out:
# 0.184

# %% [markdown]
# 5) Replot the histograms, removing the mean and normalizing by the standard deviation. Also show the CDF for normal distribution with mean zero and standard deviation of 1.

# %%
import matplotlib.mlab as mlab
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

def cointoss(tosses):
    x = np.random.rand(tosses) #making a function to simulate the coin toss experiments repeated many times
    for b in range(0, tosses):
        if x[b]<.67777:
            x[b]=0.5
        else: x[b]=-0.5
    return np.mean(x)

print cointoss(2000)

def coinhist(tosses):
    x2000 = np.zeros(2000)
    for i in range(0,2000,1):
        x2000[i] = cointoss(tosses)
    fig=plt.figure()
    n, bins, patches = plt.hist(x2000,50,normed=1, alpha=0.75) #internet sourced
    
    y= mlab.normpdf(bins, np.mean(x2000), np.std(x2000))
    l=plt.plot(bins,'r--',linewidth=2)
    plt.title(str(tosses) + ' tosses')
    plt.xlabel('mean values')
    plt.ylabel('frequency of occurance')

coinhist(2)
coinhist(16)
coinhist(64)
coinhist(256)
# Out:
# 0.184

# %% [markdown]
# Q3: Look at the Deep Cove weather data:
# There are two data sets, one with a sample every minute at
# http://web.uvic.ca/~jklymak/Phy411/Data/MinuteData/DeepCoveNew.txt.
# Download it locally, or use genfromtxt with the url as an argument.
# The second is hourly data of the same station and a lot more.
# http://web.uvic.ca/~jklymak/Phy411/Data/AllHourly.txt
# 1) Compare the normalized histograms of the two time series. Also calculate the means and the standard deviations.

# %%
minutedata=np.genfromtxt('http://web.uvic.ca/~jklymak/Phy411/Data/MinuteData/DeepCoveNew.txt')[:,1]
hourdata=np.genfromtxt('http://web.uvic.ca/~jklymak/Phy411/Data/AllHourly.txt')[6,2:]
minutedata= minutedata[~np.isnan(minutedata)]
hourdata= hourdata[~np.isnan(hourdata)]

# %%
fig= plt.figure()

ax = fig.add_subplot(2,1,1)
ax.hist(minutedata,100)
ax.set_xlabel('temperature celcius')
ax.set_ylabel('frequency of occurance (per minute)')
ax = fig.add_subplot(2,1,2)
ax.hist(hourdata,100)
ax.set_xlabel('temperature celcius')
ax.set_ylabel('frequency of occurance (per hour)')

print('means')
print(np.mean(minutedata))
print(np.mean(hourdata))
print('standard deviations')
print(np.std(minutedata))
print(np.std(hourdata))
# Out:
# means
# 10.3016961717
# 10.3387280591
# standard deviations
# 5.98530478686
# 6.06772257867

# %% [markdown]
# 2) Comment on the shape of these histograms. Are they Normal? Speculate as to why they have this shape.
#
# 2)ans: the data looks slightly skewed to the left of the center of the gaussian curve (histograms resemble this distribution)
# this is possibly because the temperature distribution is not exactly uniform.
#
# 3) Redo the histogram and the statistics with just the temperature at 3 PM (both time series start at midnight local time).

# %%
subset = hourdata[15::24] #15th point (3pm)  and then every 24th point on (24hrs)
fig= plt.figure()

ax = fig.add_subplot(1,1,1)
ax.hist(subset,100)
ax.set_xlabel('temperature celcius')
ax.set_ylabel('frequency of occurance ')

print('mean')
print(np.mean(subset))

print('standard deviation')
print(np.std(subset))

subset2 = minutedata[900::1440] # 15 hrs in*60min =  start 900th (3pm) point and then every 1440th point on (24 hrs)
fig= plt.figure()

ax = fig.add_subplot(1,1,1)
ax.hist(subset2,100)
ax.set_xlabel('temperature celcius')
ax.set_ylabel('frequency of occurance ')

print('mean')
print(np.mean(subset2))

print('standard deviation')
print(np.std(subset2))
# Out:
# mean
# 11.0903119343
# standard deviation
# 6.30206191833
# mean
# 8.63929510011
# standard deviation
# 4.44921586916

# %% [markdown]
# 4) Redo the histogram and the statistics with just the temperature at 5 AM (both time series start at midnight local time).

# %%
subset = hourdata[5::24] #5th point (5am) and then every 24th point
fig= plt.figure()

ax = fig.add_subplot(1,1,1)
ax.hist(subset,100)
ax.set_xlabel('temperature celcius')
ax.set_ylabel('frequency of occurance ')

print('mean')
print(np.mean(subset))

print('standard deviation')
print(np.std(subset))

subset2 = minutedata[300::1440] #300th point on (5*60) and then every 1440 point
fig= plt.figure()

ax = fig.add_subplot(1,1,1)
ax.hist(subset2,100)
ax.set_xlabel('temperature celcius')
ax.set_ylabel('frequency of occurance ')

print('mean')
print(np.mean(subset2))

print('standard deviation')
print(np.std(subset2))
# Out:
# mean
# 10.0081319402
# standard deviation
# 5.99111103818
# mean
# 10.618290033
# standard deviation
# 6.56947573596
